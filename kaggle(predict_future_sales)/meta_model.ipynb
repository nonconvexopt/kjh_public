# %%
from sklearn.linear_model import ElasticNet
from sklearn.decomposition import PCA
from xgboost import XGBRegressor
from xgboost import plot_importance
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from hyperopt import fmin, tpe, hp
import pandas as pd
import numpy as np
import gc
import os

# %%
train = pd.read_pickle('./data/data.pkl')
train.reset_index(inplace = False)
X_test = train.loc[train.date_block_num == 34, ['date_block_num', 'item_cnt_month']].copy()
X_test.reset_index(inplace = False)
train = train.loc[train.date_block_num <= 33, ['date_block_num', 'item_cnt_month']].copy()
train.reset_index(inplace = False)

train_files = [x for x in os.listdir("./features_train") if "feature" in x]
for file in train_files:
    temp_csv = pd.read_csv("./features_train/" + file)
    train[file] = temp_csv["item_cnt_month"].copy()
    
test_files = [x for x in os.listdir("./features") if "feature" in x]
for file in test_files:
    temp_csv = pd.read_csv("./features/" + file)
    X_test[file] = temp_csv["item_cnt_month"].copy()
    
gc.collect()
# Out:
# 0

# %%
split_train = train[train.date_block_num < 33]
split_valid = train[train.date_block_num == 33]

# %%
def val(model):
    mean_rmse = 0.0
    X = StandardScaler().fit_transform(split_train.drop(['date_block_num', 'item_cnt_month'], axis=1))
    Y = StandardScaler().fit_transform(split_train[['item_cnt_month']])
    model.fit(X, Y)
    X_new = StandardScaler().fit_transform(split_valid.drop(['date_block_num', 'item_cnt_month'], axis = 1))
    scaler = StandardScaler()
    Y_new = scaler.fit_transform(split_valid[['item_cnt_month']])
    res = mean_squared_error(
        Y_new,
        model.predict(X_new),
        squared = True
    ) * scaler.scale_
    return res

# %%
split_train.drop('date_block_num', axis = 1).corr()
# Out:
#                                item_cnt_month  feature_catboost.csv  \
# item_cnt_month                       1.000000              0.006621
# feature_catboost.csv                 0.006621              1.000000
# feature_catboost_na.csv              0.006645              0.993261
# feature_catboost_na_new.csv          0.006621              0.991632
# feature_catboost_new.csv             0.006874              0.992334
# feature_catboost_only_cat.csv        0.008274              0.781340
# feature_lgbm.csv                     0.007240              0.982097
# feature_lgbm_na.csv                  0.007177              0.973459
# feature_lgbm_na_tuned.csv            0.006801              0.974381
# feature_lgbm_tuned.csv               0.006799              0.973853
# feature_xgboost.csv                  0.006992              0.980877
# feature_xgboost_na.csv               0.006727              0.973363
# feature_xgboost_na_tuned.csv         0.006565              0.974403
# feature_xgboost_tuned.csv            0.006823              0.974738
#
#                                feature_catboost_na.csv  \
# item_cnt_month                                0.006645
# feature_catboost.csv                          0.993261
# feature_catboost_na.csv                       1.000000
# feature_catboost_na_new.csv                   0.991812
# feature_catboost_new.csv                      0.991400
# feature_catboost_only_cat.csv                 0.777901
# feature_lgbm.csv                              0.981479
# feature_lgbm_na.csv                           0.972659
# feature_lgbm_na_tuned.csv                     0.974222
# feature_lgbm_tuned.csv                        0.973692
# feature_xgboost.csv                           0.980223
# feature_xgboost_na.csv                        0.972692
# feature_xgboost_na_tuned.csv                  0.973996
# feature_xgboost_tuned.csv                     0.974260
#
#                                feature_catboost_na_new.csv  \
# item_cnt_month                                    0.006621
# feature_catboost.csv                              0.991632
# feature_catboost_na.csv                           0.991812
# feature_catboost_na_new.csv                       1.000000
# feature_catboost_new.csv                          0.987817
# feature_catboost_only_cat.csv                     0.787397
# feature_lgbm.csv                                  0.983000
# feature_lgbm_na.csv                               0.974958
# feature_lgbm_na_tuned.csv                         0.976474
# feature_lgbm_tuned.csv                            0.976038
# feature_xgboost.csv                               0.980376
# feature_xgboost_na.csv                            0.974440
# feature_xgboost_na_tuned.csv                      0.977811
# feature_xgboost_tuned.csv                         0.977452
#
#                                feature_catboost_new.csv  \
# item_cnt_month                                 0.006874
# feature_catboost.csv                           0.992334
# feature_catboost_na.csv                        0.991400
# feature_catboost_na_new.csv                    0.987817
# feature_catboost_new.csv                       1.000000
# feature_catboost_only_cat.csv                  0.767936
# feature_lgbm.csv                               0.978903
# feature_lgbm_na.csv                            0.970041
# feature_lgbm_na_tuned.csv                      0.969164
# feature_lgbm_tuned.csv                         0.968507
# feature_xgboost.csv                            0.978028
# feature_xgboost_na.csv                         0.968723
# feature_xgboost_na_tuned.csv                   0.968004
# feature_xgboost_tuned.csv                      0.969455
#
#                                feature_catboost_only_cat.csv  \
# item_cnt_month                                      0.008274
# feature_catboost.csv                                0.781340
# feature_catboost_na.csv                             0.777901
# feature_catboost_na_new.csv                         0.787397
# feature_catboost_new.csv                            0.767936
# feature_catboost_only_cat.csv                       1.000000
# feature_lgbm.csv                                    0.790575
# feature_lgbm_na.csv                                 0.796846
# feature_lgbm_na_tuned.csv                           0.806868
# feature_lgbm_tuned.csv                              0.807045
# feature_xgboost.csv                                 0.795770
# feature_xgboost_na.csv                              0.801617
# feature_xgboost_na_tuned.csv                        0.793781
# feature_xgboost_tuned.csv                           0.794807
#
#                                feature_lgbm.csv  feature_lgbm_na.csv  \
# item_cnt_month                         0.007240             0.007177
# feature_catboost.csv                   0.982097             0.973459
# feature_catboost_na.csv                0.981479             0.972659
# feature_catboost_na_new.csv            0.983000             0.974958
# feature_catboost_new.csv               0.978903             0.970041
# feature_catboost_only_cat.csv          0.790575             0.796846
# feature_lgbm.csv                       1.000000             0.992404
# feature_lgbm_na.csv                    0.992404             1.000000
# feature_lgbm_na_tuned.csv              0.983278             0.985017
# feature_lgbm_tuned.csv                 0.982752             0.984693
# feature_xgboost.csv                    0.989379             0.985871
# feature_xgboost_na.csv                 0.983844             0.985019
# feature_xgboost_na_tuned.csv           0.988223             0.982782
# feature_xgboost_tuned.csv              0.989342             0.984781
#
#                                feature_lgbm_na_tuned.csv  \
# item_cnt_month                                  0.006801
# feature_catboost.csv                            0.974381
# feature_catboost_na.csv                         0.974222
# feature_catboost_na_new.csv                     0.976474
# feature_catboost_new.csv                        0.969164
# feature_catboost_only_cat.csv                   0.806868
# feature_lgbm.csv                                0.983278
# feature_lgbm_na.csv                             0.985017
# feature_lgbm_na_tuned.csv                       1.000000
# feature_lgbm_tuned.csv                          0.999042
# feature_xgboost.csv                             0.987844
# feature_xgboost_na.csv                          0.990883
# feature_xgboost_na_tuned.csv                    0.982687
# feature_xgboost_tuned.csv                       0.982776
#
#                                feature_lgbm_tuned.csv  feature_xgboost.csv  \
# item_cnt_month                               0.006799             0.006992
# feature_catboost.csv                         0.973853             0.980877
# feature_catboost_na.csv                      0.973692             0.980223
# feature_catboost_na_new.csv                  0.976038             0.980376
# feature_catboost_new.csv                     0.968507             0.978028
# feature_catboost_only_cat.csv                0.807045             0.795770
# feature_lgbm.csv                             0.982752             0.989379
# feature_lgbm_na.csv                          0.984693             0.985871
# feature_lgbm_na_tuned.csv                    0.999042             0.987844
# feature_lgbm_tuned.csv                       1.000000             0.987302
# feature_xgboost.csv                          0.987302             1.000000
# feature_xgboost_na.csv                       0.990526             0.993058
# feature_xgboost_na_tuned.csv                 0.982251             0.982603
# feature_xgboost_tuned.csv                    0.982766             0.983782
#
#                                feature_xgboost_na.csv  \
# item_cnt_month                               0.006727
# feature_catboost.csv                         0.973363
# feature_catboost_na.csv                      0.972692
# feature_catboost_na_new.csv                  0.974440
# feature_catboost_new.csv                     0.968723
# feature_catboost_only_cat.csv                0.801617
# feature_lgbm.csv                             0.983844
# feature_lgbm_na.csv                          0.985019
# feature_lgbm_na_tuned.csv                    0.990883
# feature_lgbm_tuned.csv                       0.990526
# feature_xgboost.csv                          0.993058
# feature_xgboost_na.csv                       1.000000
# feature_xgboost_na_tuned.csv                 0.980334
# feature_xgboost_tuned.csv                    0.981351
#
#                                feature_xgboost_na_tuned.csv  \
# item_cnt_month                                     0.006565
# feature_catboost.csv                               0.974403
# feature_catboost_na.csv                            0.973996
# feature_catboost_na_new.csv                        0.977811
# feature_catboost_new.csv                           0.968004
# feature_catboost_only_cat.csv                      0.793781
# feature_lgbm.csv                                   0.988223
# feature_lgbm_na.csv                                0.982782
# feature_lgbm_na_tuned.csv                          0.982687
# feature_lgbm_tuned.csv                             0.982251
# feature_xgboost.csv                                0.982603
# feature_xgboost_na.csv                             0.980334
# feature_xgboost_na_tuned.csv                       1.000000
# feature_xgboost_tuned.csv                          0.992259
#
#                                feature_xgboost_tuned.csv
# item_cnt_month                                  0.006823
# feature_catboost.csv                            0.974738
# feature_catboost_na.csv                         0.974260
# feature_catboost_na_new.csv                     0.977452
# feature_catboost_new.csv                        0.969455
# feature_catboost_only_cat.csv                   0.794807
# feature_lgbm.csv                                0.989342
# feature_lgbm_na.csv                             0.984781
# feature_lgbm_na_tuned.csv                       0.982776
# feature_lgbm_tuned.csv                          0.982766
# feature_xgboost.csv                             0.983782
# feature_xgboost_na.csv                          0.981351
# feature_xgboost_na_tuned.csv                    0.992259
# feature_xgboost_tuned.csv                       1.000000

# %%
pca = PCA(whiten=True).fit(split_train.drop(['item_cnt_month', 'date_block_num'], axis = 1))

# %%
pca.transform(split_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-0d631faa31d2> in <module>
# ----> 1 pca.transform(split_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\decomposition\_base.py in transform(self, X)
#     127         X = check_array(X)
#     128         if self.mean_ is not None:
# --> 129             X = X - self.mean_
#     130         X_transformed = np.dot(X, self.components_.T)
#     131         if self.whiten:
#
# ValueError: operands could not be broadcast together with shapes (2430227,15) (13,)

# %%
#Search space
param_space = {'alpha': hp.uniform('alpha', np.log(1e-4), np.log(1)),
               'l1_ratio': hp.loguniform('l1_ratio', np.log(1e-4), np.log(1))}

#objective
def objective(params):   
    return val(ElasticNet(alpha=params['alpha'], l1_ratio=params['l1_ratio']), tol)[0]

#run
best = fmin(fn=objective, space=param_space, 
            max_evals=50, 
            rstate=np.random.RandomState(777), 
            algo=tpe.suggest)
print(best)
# Out:
#   0%|                                                                           | 0/50 [00:00<?, ?trial/s, best loss=?]
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 243.02269733463294
#   positive)
#   2%|▉                                                | 1/50 [00:31<25:34, 31.33s/trial, best loss: 1.2287627143813749]
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 243.02269733463294
#   positive)
#   4%|█▉                                               | 2/50 [01:04<25:26, 31.80s/trial, best loss: 1.2287627143813749]
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 243.02269733463294
#   positive)
#   6%|██▉                                              | 3/50 [02:09<33:41, 43.02s/trial, best loss: 1.2287627143813749]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-5cdb4f096842> in <module>
#      11             max_evals=50,
#      12             rstate=np.random.RandomState(777),
# ---> 13             algo=tpe.suggest)
#      14 print(best)
#
# C:\ProgramData\Anaconda3\lib\site-packages\hyperopt\fmin.py in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar)
#     507
#     508     # next line is where the fmin is actually executed
# --> 509     rval.exhaust()
#     510
#     511     if return_argmin:
#
# C:\ProgramData\Anaconda3\lib\site-packages\hyperopt\fmin.py in exhaust(self)
#     328     def exhaust(self):
#     329         n_done = len(self.trials)
# --> 330         self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     331         self.trials.refresh()
#     332         return self
#
# C:\ProgramData\Anaconda3\lib\site-packages\hyperopt\fmin.py in run(self, N, block_until_done)
#     284                 else:
#     285                     # -- loop over trials and do the jobs directly
# --> 286                     self.serial_evaluate()
#     287
#     288                 self.trials.refresh()
#
# C:\ProgramData\Anaconda3\lib\site-packages\hyperopt\fmin.py in serial_evaluate(self, N)
#     163                 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     164                 try:
# --> 165                     result = self.domain.evaluate(spec, ctrl)
#     166                 except Exception as e:
#     167                     logger.error("job exception: %s" % str(e))
#
# C:\ProgramData\Anaconda3\lib\site-packages\hyperopt\base.py in evaluate(self, config, ctrl, attach_attachments)
#     892                 print_node_on_error=self.rec_eval_print_node_on_error,
#     893             )
# --> 894             rval = self.fn(pyll_rval)
#     895
#     896         if isinstance(rval, (float, int, np.number)):
#
# <ipython-input-9-5cdb4f096842> in objective(params)
#       5 #objective
#       6 def objective(params):
# ----> 7     return val(ElasticNet(alpha=params['alpha'], l1_ratio=params['l1_ratio']))[0]
#       8
#       9 #run
#
# <ipython-input-4-5c9bdede98f4> in val(model)
#       3     X = StandardScaler().fit_transform(split_train.drop(['date_block_num', 'item_cnt_month'], axis=1))
#       4     Y = StandardScaler().fit_transform(split_train[['item_cnt_month']])
# ----> 5     model.fit(X, Y)
#       6     X_new = StandardScaler().fit_transform(split_valid.drop(['date_block_num', 'item_cnt_month'], axis = 1))
#       7     scaler = StandardScaler()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py in fit(self, X, y, check_input)
#     749                           random_state=self.random_state,
#     750                           selection=self.selection,
# --> 751                           check_input=False)
#     752             coef_[k] = this_coef[:, 0]
#     753             dual_gaps_[k] = this_dual_gap[0]
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py in enet_path(X, y, l1_ratio, eps, n_alphas, alphas, precompute, Xy, copy_X, coef_init, verbose, return_n_iter, positive, check_input, **params)
#     474             model = cd_fast.enet_coordinate_descent(
#     475                 coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random,
# --> 476                 positive)
#     477         else:
#     478             raise ValueError("Precompute should be one of True, False, "
#
# sklearn\linear_model\_cd_fast.pyx in sklearn.linear_model._cd_fast.enet_coordinate_descent()
#
# KeyboardInterrupt:

# %%
val(ElasticNet(alpha=0.2, l1_ratio=0.8))
# Out:
# 0.7027797536503817

# %%
model = ElasticNet(alpha=0.2, l1_ratio=0.8)
model.fit(train.drop(['item_cnt_month'], axis=1), train['item_cnt_month'])
X_test["item_cnt_month"] = model.predict(X_test.drop(['item_cnt_month'], axis = 1))

# %%
sub = pd.read_csv("./data/sample_submission.csv")
sub.reset_index(inplace = False)
sub['item_cnt_month'] = X_test["item_cnt_month"]
sub.to_csv("./submission.csv", index=False)
